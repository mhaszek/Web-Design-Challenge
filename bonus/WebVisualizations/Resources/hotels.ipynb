# %%
# import dependencies
import pandas as pd

# %%
# impport cities file into DataFrame
hotels_df = pd.read_csv('hotels.csv', low_memory=False)

# %%
# display the results
hotels_df
# Out:
#    City_ID        City  Cloudiness Country        Date  Humidity      Lat  \
# 0       48        atar           0      MR  1616122485        13  20.5169
# 1      145     salalah           0      OM  1616122415        43  17.0151
# 2      181    umm lajj           0      SA  1616122623        45  25.0213
# 3      233       nizwa           0      OM  1616122824        24  22.9333
# 4      263        nara           0      JP  1616122826        39  34.6851
# 5      267        ibra           0      OM  1616122833        31  22.6906
# 6      486      yazman           0      PK  1616122899        31  29.1212
# 7      573      viedma           0      AR  1616122414        37 -40.8135
# 8      588  bahawalpur           0      PK  1616122796        36  29.4000
#
#         Lng  Max Temp  Wind Speed                   Hotel Name
# 0  -13.0499     20.90        1.64                   Bab Sahara
# 1   54.0924     22.00        1.54  Star Emirates garden villas
# ...

# %%
del hotels_df['Unnamed: 0']

# %%
# save the DataFrame to a html file
hotels_df.to_html('hotels.html', index=False)
